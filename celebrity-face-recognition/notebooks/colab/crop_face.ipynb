# %%
# !pip install facenet_pytorch
# !pip install pillow==6.2.1
# Out:
# Requirement already satisfied: facenet_pytorch in /usr/local/lib/python3.6/dist-packages (1.0.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from facenet_pytorch) (1.17.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from facenet_pytorch) (2.21.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->facenet_pytorch) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->facenet_pytorch) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->facenet_pytorch) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->facenet_pytorch) (1.24.3)
# Requirement already satisfied: pillow==6.2.1 in /usr/local/lib/python3.6/dist-packages (6.2.1)

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !rm -rf /content/drive/My\ Drive/celebrity-face-recognition/data

# %%
# !cp /content/drive/My\ Drive/celebrity-face-recognition ./ -r

# %%
# %cd celebrity-face-recognition/
# Out:
# /content/celebrity-face-recognition

# %%
# !rm -r data
# !mkdir data
# !mkdir data/raw
# !mkdir data/processed

# %%
# !cp -r -t data/raw/ downloads/*

# %%
import os


def walkdir(folder):
    """Walk through each files in a directory"""
    for dirpath, dirs, files in os.walk(folder):
        for filename in files:
            yield os.path.abspath(os.path.join(dirpath, filename))

# %%
celeb_names = os.listdir('data/raw')

# %%
import torch


class Config:
    def __init__(self):
        self.epoch = 200
        self.train_patience = 10

        self.batch_size = 32
        self.valid_ratio = 0.2
        self.test_ratio = 0.2

        self.lr = 0.0001

        self.seed = 420
        self.device = torch.device('cuda:0')
        
        self.num_workers = 1
        self.pin_memory = True
    
        # config for mtcnn

        self.image_size = 160
        self.margin = 0
        self.min_face_size = 20
        self.threshold = [0.6, 0.7, 0.7]
        self.factor = 0.709
        self.prewhiten = True

# %%
import os
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, transforms
from sklearn.model_selection import train_test_split
import numpy as np

from control import RAW_DATA_PATH, PROCESSED_DATA_PATH


class CropFaceDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

    def __len__(self):
        return len(X)


def get_dataloader(batch_size: int,
                   test_ratio=0.2,
                   valid_ratio=0.2,
                   random_state=420,
                   shuffle=True,
                   num_workers=4,
                   pin_memory=False):
    src_folder = os.path.join(PROCESSED_DATA_PATH, 'cropped')

    transforms_img = transforms.Compose([transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
                                         transforms.RandomRotation(degrees=15),
                                         transforms.ColorJitter(),
                                         transforms.RandomHorizontalFlip(),
                                         transforms.CenterCrop(size=224),  # Image net standards
                                         transforms.ToTensor(),
                                         transforms.Normalize([0.485, 0.456, 0.406],
                                                              [0.229, 0.224, 0.225])
                                         ])
    dataset = datasets.ImageFolder(src_folder, transform=transforms_img)

    X = [i for i, j in dataset.imgs]
    y = [j for i, j in dataset.imgs]

    X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                        test_size=test_ratio,
                                                        random_state=random_state,
                                                        shuffle=shuffle,
                                                        stratify=y)

    X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train,
                                                          test_size=valid_ratio,
                                                          random_state=random_state,
                                                          shuffle=shuffle,
                                                          stratify=y_train)

    train_set = CropFaceDataset(X_train, y_train)
    valid_set = CropFaceDataset(X_valid, y_valid)
    test_set = CropFaceDataset(X_test, y_test)

    train_loader = DataLoader(train_set, batch_size=batch_size, num_workers=num_workers, pin_memory=pin_memory,
                              collate_fn=collate_pil)
    valid_loader = DataLoader(valid_set, batch_size=batch_size, num_workers=num_workers, pin_memory=pin_memory,
                              collate_fn=collate_pil)
    test_loader = DataLoader(test_set, batch_size=batch_size, num_workers=num_workers, pin_memory=pin_memory,
                             collate_fn=collate_pil)

    return train_loader, valid_loader, test_loader, dataset.class_to_idx


def create_cropped_face_dataset(mtcnn,
                                size,
                                batch_size: int,
                                num_workers=4,
                                pin_memory=False):
    dest_folder = os.path.join(PROCESSED_DATA_PATH, 'cropped')
    src_folder = RAW_DATA_PATH

    dataset = datasets.ImageFolder(src_folder, transform=transforms.Resize((size, size)))
    dataset.samples = [(p, p.replace(src_folder, dest_folder)) for p, _ in dataset.samples]

    loader = DataLoader(dataset,
                        batch_size=1,
                        num_workers=num_workers,
                        pin_memory=pin_memory,
                        collate_fn=collate_pil)

    for i, (x, y) in enumerate(loader):
        print('\rImages processed: {:8d} of {:8d}'.format(i + 1, len(loader)), end='')
        mtcnn(x, save_path=y)
        print((x, y))


def collate_pil(x):
    out_x, out_y = [], []
    for xx, yy in x:
        out_x.append(xx)
        out_y.append(yy)
    return out_x, out_y

# %%
from facenet_pytorch import MTCNN

cfg = Config()
mtcnn = MTCNN(
    image_size=cfg.image_size,
    margin=cfg.margin,
    min_face_size=cfg.min_face_size,
    thresholds=cfg.threshold,
    factor=cfg.factor,
    # prewhiten=cfg.prewhiten,
    keep_all=True,
    device=cfg.device)

create_cropped_face_dataset(mtcnn,
                            160,
                            cfg.batch_size,
                            cfg.num_workers,
                            cfg.pin_memory)

del mtcnn
# Out:
# Images processed:        1 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935024E0>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_1.png'])
# Images processed:        2 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502940>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_10.png'])
# Images processed:        3 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502208>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_11.png'])
# Images processed:        4 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502198>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_12.png'])
# Images processed:        5 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502208>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_13.png'])
# Images processed:        6 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502EB8>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_14.png'])
# Images processed:        7 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502198>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_15.png'])
# Images processed:        8 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502E48>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_16.png'])
# Images processed:        9 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935024E0>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_17.png'])
# Images processed:       10 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502E10>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_18.png'])
# Images processed:       11 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502E48>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_19.png'])
# Images processed:       12 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502A90>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_2.png'])
# Images processed:       13 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502908>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_20.png'])
# Images processed:       14 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502A90>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_21.png'])
# Images processed:       15 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935022B0>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_22.png'])
# Images processed:       16 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502FD0>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_23.png'])
# Images processed:       17 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502EF0>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_24.png'])
# Images processed:       18 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502940>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_25.png'])
# Images processed:       19 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502898>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_26.png'])
# Images processed:       20 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935026A0>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_27.png'])
# Images processed:       21 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935023C8>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_28.png'])
# Images processed:       22 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502EF0>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_29.png'])
# Images processed:       23 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502E10>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_3.png'])
# Images processed:       24 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935021D0>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_30.png'])
# Images processed:       25 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935025C0>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_31.png'])
# Images processed:       26 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502550>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_32.png'])
# Images processed:       27 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502908>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_33.png'])
# Images processed:       28 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502F60>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_34.png'])
# Images processed:       29 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502898>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_35.png'])
# Images processed:       30 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935023C8>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_36.png'])
# Images processed:       31 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502898>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_4.png'])
# Images processed:       32 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502908>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_5.png'])
# Images processed:       33 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502940>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_6.png'])
# Images processed:       34 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502668>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_7.png'])
# Images processed:       35 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502EF0>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_8.png'])
# Images processed:       36 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935026A0>], ['/content/celebrity-face-recognition/data/processed/cropped/Bang Kieu/Bang Kieu_9.png'])
# Images processed:       37 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935025C0>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_1.png'])
# Images processed:       38 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502390>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_10.png'])
# Images processed:       39 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502358>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_11.png'])
# Images processed:       40 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502940>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_12.png'])
# Images processed:       41 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502198>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_13.png'])
# Images processed:       42 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502A90>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_14.png'])
# Images processed:       43 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935022B0>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_15.png'])
# Images processed:       44 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935025C0>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_16.png'])
# Images processed:       45 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502668>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_17.png'])
# Images processed:       46 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502F60>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_18.png'])
# Images processed:       47 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502E10>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_19.png'])
# Images processed:       48 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502898>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_2.PNG'])
# Images processed:       49 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502198>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_20.png'])
# Images processed:       50 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935025C0>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_21.png'])
# Images processed:       51 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502EF0>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_22.png'])
# Images processed:       52 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502358>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_23.png'])
# Images processed:       53 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502EF0>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_24.png'])
# Images processed:       54 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502358>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_25.png'])
# Images processed:       55 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502668>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_26.png'])
# Images processed:       56 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502FD0>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_27.png'])
# Images processed:       57 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502668>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_28.png'])
# Images processed:       58 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502390>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_29.png'])
# Images processed:       59 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935021D0>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_3.png'])
# Images processed:       60 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502EF0>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_30.png'])
# Images processed:       61 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502940>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_31.png'])
# Images processed:       62 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935025F8>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_32.png'])
# Images processed:       63 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935023C8>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_33.png'])
# Images processed:       64 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502FD0>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_34.png'])
# Images processed:       65 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502940>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_35.png'])
# Images processed:       66 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935026A0>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_4.png'])
# Images processed:       67 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502198>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_5.png'])
# Images processed:       68 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935022B0>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_6.png'])
# Images processed:       69 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935023C8>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_7.png'])
# Images processed:       70 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502198>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_8.png'])
# Images processed:       71 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935025F8>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Anh Tuan/Bui Anh Tuan_9.png'])
# Images processed:       72 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502198>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Tien Dung/Bui Tien Dung_1.png'])
# Images processed:       73 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502668>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Tien Dung/Bui Tien Dung_10.png'])
# Images processed:       74 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502FD0>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Tien Dung/Bui Tien Dung_11.png'])
# Images processed:       75 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502668>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Tien Dung/Bui Tien Dung_12.png'])
# Images processed:       76 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502A90>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Tien Dung/Bui Tien Dung_13.png'])
# Images processed:       77 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502A20>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Tien Dung/Bui Tien Dung_14.png'])
# Images processed:       78 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502A90>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Tien Dung/Bui Tien Dung_15.png'])
# Images processed:       79 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502A20>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Tien Dung/Bui Tien Dung_16.png'])
# Images processed:       80 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502A90>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Tien Dung/Bui Tien Dung_17.png'])
# Images processed:       81 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502A20>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Tien Dung/Bui Tien Dung_18.png'])
# Images processed:       82 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502390>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Tien Dung/Bui Tien Dung_19.png'])
# Images processed:       83 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502A90>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Tien Dung/Bui Tien Dung_2.png'])
# Images processed:       84 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502358>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Tien Dung/Bui Tien Dung_20.png'])
# Images processed:       85 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502FD0>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Tien Dung/Bui Tien Dung_21.png'])
# Images processed:       86 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502F60>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Tien Dung/Bui Tien Dung_22.png'])
# Images processed:       87 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502390>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Tien Dung/Bui Tien Dung_23.png'])
# Images processed:       88 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502898>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Tien Dung/Bui Tien Dung_24.png'])
# Images processed:       89 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502358>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Tien Dung/Bui Tien Dung_25.png'])
# Images processed:       90 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502940>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Tien Dung/Bui Tien Dung_26.png'])
# Images processed:       91 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935024E0>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Tien Dung/Bui Tien Dung_27.png'])
# Images processed:       92 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502EF0>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Tien Dung/Bui Tien Dung_28.png'])
# Images processed:       93 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502358>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Tien Dung/Bui Tien Dung_29.png'])
# Images processed:       94 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502F60>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Tien Dung/Bui Tien Dung_3.png'])
# Images processed:       95 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935021D0>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Tien Dung/Bui Tien Dung_30.png'])
# Images processed:       96 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502EF0>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Tien Dung/Bui Tien Dung_4.png'])
# Images processed:       97 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935025F8>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Tien Dung/Bui Tien Dung_5.png'])
# Images processed:       98 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502FD0>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Tien Dung/Bui Tien Dung_6.png'])
# Images processed:       99 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935021D0>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Tien Dung/Bui Tien Dung_7.png'])
# Images processed:      100 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502A20>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Tien Dung/Bui Tien Dung_8.png'])
# Images processed:      101 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502668>], ['/content/celebrity-face-recognition/data/processed/cropped/Bui Tien Dung/Bui Tien Dung_9.png'])
# Images processed:      102 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935024E0>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Dan/Chi Dan_1.png'])
# Images processed:      103 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935025F8>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Dan/Chi Dan_10.png'])
# Images processed:      104 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502940>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Dan/Chi Dan_11.png'])
# Images processed:      105 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502390>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Dan/Chi Dan_12.png'])
# Images processed:      106 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502898>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Dan/Chi Dan_13.png'])
# Images processed:      107 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502E10>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Dan/Chi Dan_14.png'])
# Images processed:      108 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935021D0>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Dan/Chi Dan_15.png'])
# Images processed:      109 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502EF0>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Dan/Chi Dan_16.PNG'])
# Images processed:      110 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935024E0>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Dan/Chi Dan_17.png'])
# Images processed:      111 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502E10>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Dan/Chi Dan_18.png'])
# Images processed:      112 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935025C0>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Dan/Chi Dan_19.png'])
# Images processed:      113 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502390>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Dan/Chi Dan_2.png'])
# Images processed:      114 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935022B0>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Dan/Chi Dan_20.png'])
# Images processed:      115 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502390>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Dan/Chi Dan_3.png'])
# Images processed:      116 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502550>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Dan/Chi Dan_4.png'])
# Images processed:      117 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502940>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Dan/Chi Dan_5.png'])
# Images processed:      118 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502EF0>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Dan/Chi Dan_6.png'])
# Images processed:      119 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502FD0>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Dan/Chi Dan_7.png'])
# Images processed:      120 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502940>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Dan/Chi Dan_8.png'])
# Images processed:      121 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502908>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Dan/Chi Dan_9.png'])
# Images processed:      122 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502E10>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_1.png'])
# Images processed:      123 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935022B0>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_10.png'])
# Images processed:      124 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502940>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_11.png'])
# Images processed:      125 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502278>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_12.png'])
# Images processed:      126 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502E10>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_13.png'])
# Images processed:      127 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502EF0>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_14.png'])
# Images processed:      128 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502390>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_15.png'])
# Images processed:      129 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502630>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_16.png'])
# Images processed:      130 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935026A0>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_17.png'])
# Images processed:      131 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502390>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_18.png'])
# Images processed:      132 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502E10>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_19.png'])
# Images processed:      133 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502550>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_2.png'])
# Images processed:      134 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502278>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_20.png'])
# Images processed:      135 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502550>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_21.png'])
# Images processed:      136 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502FD0>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_22.png'])
# Images processed:      137 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935026A0>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_23.png'])
# Images processed:      138 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502668>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_24.png'])
# Images processed:      139 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935026A0>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_25.png'])
# Images processed:      140 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502668>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_26.png'])
# Images processed:      141 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502630>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_27.png'])
# Images processed:      142 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502278>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_28.png'])
# Images processed:      143 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935022B0>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_29.png'])
# Images processed:      144 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502668>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_3.png'])
# Images processed:      145 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502E10>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_30.png'])
# Images processed:      146 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935024E0>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_31.png'])
# Images processed:      147 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935025F8>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_32.png'])
# Images processed:      148 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502940>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_33.png'])
# Images processed:      149 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935023C8>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_34.png'])
# Images processed:      150 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502668>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_35.png'])
# Images processed:      151 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502630>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_36.png'])
# Images processed:      152 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502908>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_37.png'])
# Images processed:      153 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935024E0>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_38.png'])
# Images processed:      154 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502A90>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_39.png'])
# Images processed:      155 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502E10>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_4.png'])
# Images processed:      156 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502390>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_5.png'])
# Images processed:      157 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935024E0>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_6.png'])
# Images processed:      158 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502A20>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_7.png'])
# Images processed:      159 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502358>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_8.png'])
# Images processed:      160 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502668>], ['/content/celebrity-face-recognition/data/processed/cropped/Chi Pu/Chi Pu_9.png'])
# Images processed:      161 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502358>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_1.PNG'])
# Images processed:      162 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502908>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_10.png'])
# Images processed:      163 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502390>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_11.png'])
# Images processed:      164 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502A20>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_12.png'])
# Images processed:      165 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502358>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_13.png'])
# Images processed:      166 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502908>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_14.png'])
# Images processed:      167 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502F60>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_15.PNG'])
# Images processed:      168 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502390>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_16.png'])
# Images processed:      169 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502EF0>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_17.png'])
# Images processed:      170 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502940>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_18.png'])
# Images processed:      171 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502A20>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_19.png'])
# Images processed:      172 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502E48>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_2.PNG'])
# Images processed:      173 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935026A0>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_20.png'])
# Images processed:      174 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502F60>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_21.png'])
# Images processed:      175 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502EF0>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_22.png'])
# Images processed:      176 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502A20>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_23.png'])
# Images processed:      177 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502390>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_24.png'])
# Images processed:      178 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935026A0>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_25.png'])
# Images processed:      179 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935022B0>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_26.png'])
# Images processed:      180 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502390>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_27.png'])
# Images processed:      181 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935025F8>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_28.PNG'])
# Images processed:      182 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935022B0>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_29.png'])
# Images processed:      183 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935026A0>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_3.png'])
# Images processed:      184 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502198>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_30.png'])
# Images processed:      185 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502940>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_31.png'])
# Images processed:      186 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502358>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_32.png'])
# Images processed:      187 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502EF0>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_33.png'])
# Images processed:      188 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502240>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_34.png'])
# Images processed:      189 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502630>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_35.png'])
# Images processed:      190 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502A90>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_36.png'])
# Images processed:      191 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502358>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_4.png'])
# Images processed:      192 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502E10>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_5.png'])
# Images processed:      193 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502A20>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_6.png'])
# Images processed:      194 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502EF0>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_7.png'])
# Images processed:      195 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502F60>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_8.png'])
# Images processed:      196 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502E10>], ['/content/celebrity-face-recognition/data/processed/cropped/Dam Vinh Hung/Dam Vinh Hung_9.png'])
# Images processed:      197 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502A90>], ['/content/celebrity-face-recognition/data/processed/cropped/Den Vau/Den Vau_1.png'])
# Images processed:      198 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502550>], ['/content/celebrity-face-recognition/data/processed/cropped/Den Vau/Den Vau_10.png'])
# Images processed:      199 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935026A0>], ['/content/celebrity-face-recognition/data/processed/cropped/Den Vau/Den Vau_11.png'])
# Images processed:      200 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935022B0>], ['/content/celebrity-face-recognition/data/processed/cropped/Den Vau/Den Vau_12.png'])
# Images processed:      201 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502278>], ['/content/celebrity-face-recognition/data/processed/cropped/Den Vau/Den Vau_13.png'])
# Images processed:      202 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502EF0>], ['/content/celebrity-face-recognition/data/processed/cropped/Den Vau/Den Vau_14.png'])
# Images processed:      203 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502278>], ['/content/celebrity-face-recognition/data/processed/cropped/Den Vau/Den Vau_15.PNG'])
# Images processed:      204 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502EF0>], ['/content/celebrity-face-recognition/data/processed/cropped/Den Vau/Den Vau_16.png'])
# Images processed:      205 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502A20>], ['/content/celebrity-face-recognition/data/processed/cropped/Den Vau/Den Vau_17.png'])
# Images processed:      206 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502EF0>], ['/content/celebrity-face-recognition/data/processed/cropped/Den Vau/Den Vau_2.png'])
# Images processed:      207 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502A20>], ['/content/celebrity-face-recognition/data/processed/cropped/Den Vau/Den Vau_3.png'])
# Images processed:      208 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502EF0>], ['/content/celebrity-face-recognition/data/processed/cropped/Den Vau/Den Vau_4.png'])
# Images processed:      209 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502940>], ['/content/celebrity-face-recognition/data/processed/cropped/Den Vau/Den Vau_5.png'])
# Images processed:      210 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935023C8>], ['/content/celebrity-face-recognition/data/processed/cropped/Den Vau/Den Vau_6.png'])
# Images processed:      211 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502550>], ['/content/celebrity-face-recognition/data/processed/cropped/Den Vau/Den Vau_7.png'])
# Images processed:      212 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502390>], ['/content/celebrity-face-recognition/data/processed/cropped/Den Vau/Den Vau_8.png'])
# Images processed:      213 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502898>], ['/content/celebrity-face-recognition/data/processed/cropped/Den Vau/Den Vau_9.png'])
# Images processed:      214 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502390>], ['/content/celebrity-face-recognition/data/processed/cropped/Dong Nhi/Dong Nhi_1.png'])
# Images processed:      215 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935025C0>], ['/content/celebrity-face-recognition/data/processed/cropped/Dong Nhi/Dong Nhi_10.png'])
# Images processed:      216 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935022B0>], ['/content/celebrity-face-recognition/data/processed/cropped/Dong Nhi/Dong Nhi_11.png'])
# Images processed:      217 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502EB8>], ['/content/celebrity-face-recognition/data/processed/cropped/Dong Nhi/Dong Nhi_12.PNG'])
# Images processed:      218 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502E48>], ['/content/celebrity-face-recognition/data/processed/cropped/Dong Nhi/Dong Nhi_13.png'])
# Images processed:      219 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502FD0>], ['/content/celebrity-face-recognition/data/processed/cropped/Dong Nhi/Dong Nhi_14.png'])
# Images processed:      220 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502F60>], ['/content/celebrity-face-recognition/data/processed/cropped/Dong Nhi/Dong Nhi_15.png'])
# Images processed:      221 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502278>], ['/content/celebrity-face-recognition/data/processed/cropped/Dong Nhi/Dong Nhi_16.png'])
# Images processed:      222 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502198>], ['/content/celebrity-face-recognition/data/processed/cropped/Dong Nhi/Dong Nhi_17.png'])
# Images processed:      223 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935022B0>], ['/content/celebrity-face-recognition/data/processed/cropped/Dong Nhi/Dong Nhi_18.png'])
# Images processed:      224 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502F60>], ['/content/celebrity-face-recognition/data/processed/cropped/Dong Nhi/Dong Nhi_19.png'])
# Images processed:      225 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935022B0>], ['/content/celebrity-face-recognition/data/processed/cropped/Dong Nhi/Dong Nhi_2.png'])
# Images processed:      226 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502550>], ['/content/celebrity-face-recognition/data/processed/cropped/Dong Nhi/Dong Nhi_20.png'])
# Images processed:      227 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502FD0>], ['/content/celebrity-face-recognition/data/processed/cropped/Dong Nhi/Dong Nhi_21.png'])
# Images processed:      228 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502A90>], ['/content/celebrity-face-recognition/data/processed/cropped/Dong Nhi/Dong Nhi_22.png'])
# Images processed:      229 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935022B0>], ['/content/celebrity-face-recognition/data/processed/cropped/Dong Nhi/Dong Nhi_23.png'])
# Images processed:      230 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502EF0>], ['/content/celebrity-face-recognition/data/processed/cropped/Dong Nhi/Dong Nhi_24.png'])
# Images processed:      231 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502198>], ['/content/celebrity-face-recognition/data/processed/cropped/Dong Nhi/Dong Nhi_25.png'])
# Images processed:      232 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935022B0>], ['/content/celebrity-face-recognition/data/processed/cropped/Dong Nhi/Dong Nhi_26.png'])
# Images processed:      233 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502198>], ['/content/celebrity-face-recognition/data/processed/cropped/Dong Nhi/Dong Nhi_27.png'])
# Images processed:      234 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935025F8>], ['/content/celebrity-face-recognition/data/processed/cropped/Dong Nhi/Dong Nhi_28.png'])
# Images processed:      235 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502EF0>], ['/content/celebrity-face-recognition/data/processed/cropped/Dong Nhi/Dong Nhi_29.png'])
# Images processed:      236 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935025F8>], ['/content/celebrity-face-recognition/data/processed/cropped/Dong Nhi/Dong Nhi_3.png'])
# Images processed:      237 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935022B0>], ['/content/celebrity-face-recognition/data/processed/cropped/Dong Nhi/Dong Nhi_30.png'])
# Images processed:      238 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502630>], ['/content/celebrity-face-recognition/data/processed/cropped/Dong Nhi/Dong Nhi_31.png'])
# Images processed:      239 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502A90>], ['/content/celebrity-face-recognition/data/processed/cropped/Dong Nhi/Dong Nhi_32.png'])
# Images processed:      240 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502EB8>], ['/content/celebrity-face-recognition/data/processed/cropped/Dong Nhi/Dong Nhi_33.png'])
# Images processed:      241 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502198>], ['/content/celebrity-face-recognition/data/processed/cropped/Dong Nhi/Dong Nhi_34.png'])
# Images processed:      242 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935023C8>], ['/content/celebrity-face-recognition/data/processed/cropped/Dong Nhi/Dong Nhi_35.png'])
# ...
# Images processed:     1031 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502E10>], ['/content/celebrity-face-recognition/data/processed/cropped/Vu Cat Tuong/Vu Cat Tuong_2.png'])
# Images processed:     1032 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502390>], ['/content/celebrity-face-recognition/data/processed/cropped/Vu Cat Tuong/Vu Cat Tuong_20.png'])
# Images processed:     1033 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502198>], ['/content/celebrity-face-recognition/data/processed/cropped/Vu Cat Tuong/Vu Cat Tuong_21.png'])
# Images processed:     1034 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502940>], ['/content/celebrity-face-recognition/data/processed/cropped/Vu Cat Tuong/Vu Cat Tuong_22.png'])
# Images processed:     1035 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502E48>], ['/content/celebrity-face-recognition/data/processed/cropped/Vu Cat Tuong/Vu Cat Tuong_23.png'])
# Images processed:     1036 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502208>], ['/content/celebrity-face-recognition/data/processed/cropped/Vu Cat Tuong/Vu Cat Tuong_24.png'])
# Images processed:     1037 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502908>], ['/content/celebrity-face-recognition/data/processed/cropped/Vu Cat Tuong/Vu Cat Tuong_25.png'])
# Images processed:     1038 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502FD0>], ['/content/celebrity-face-recognition/data/processed/cropped/Vu Cat Tuong/Vu Cat Tuong_3.png'])
# Images processed:     1039 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502668>], ['/content/celebrity-face-recognition/data/processed/cropped/Vu Cat Tuong/Vu Cat Tuong_4.png'])
# Images processed:     1040 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935026A0>], ['/content/celebrity-face-recognition/data/processed/cropped/Vu Cat Tuong/Vu Cat Tuong_5.png'])
# Images processed:     1041 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502668>], ['/content/celebrity-face-recognition/data/processed/cropped/Vu Cat Tuong/Vu Cat Tuong_6.png'])
# Images processed:     1042 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502278>], ['/content/celebrity-face-recognition/data/processed/cropped/Vu Cat Tuong/Vu Cat Tuong_7.png'])
# Images processed:     1043 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502FD0>], ['/content/celebrity-face-recognition/data/processed/cropped/Vu Cat Tuong/Vu Cat Tuong_8.png'])
# Images processed:     1044 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502198>], ['/content/celebrity-face-recognition/data/processed/cropped/Vu Cat Tuong/Vu Cat Tuong_9.png'])
# Images processed:     1045 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502390>], ['/content/celebrity-face-recognition/data/processed/cropped/Xuan Bac/Xuan Bac_1.png'])
# Images processed:     1046 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502668>], ['/content/celebrity-face-recognition/data/processed/cropped/Xuan Bac/Xuan Bac_10.png'])
# Images processed:     1047 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502FD0>], ['/content/celebrity-face-recognition/data/processed/cropped/Xuan Bac/Xuan Bac_11.png'])
# Images processed:     1048 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502E10>], ['/content/celebrity-face-recognition/data/processed/cropped/Xuan Bac/Xuan Bac_12.png'])
# Images processed:     1049 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935026A0>], ['/content/celebrity-face-recognition/data/processed/cropped/Xuan Bac/Xuan Bac_13.png'])
# Images processed:     1050 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502668>], ['/content/celebrity-face-recognition/data/processed/cropped/Xuan Bac/Xuan Bac_14.png'])
# Images processed:     1051 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502198>], ['/content/celebrity-face-recognition/data/processed/cropped/Xuan Bac/Xuan Bac_15.png'])
# Images processed:     1052 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502E10>], ['/content/celebrity-face-recognition/data/processed/cropped/Xuan Bac/Xuan Bac_16.png'])
# Images processed:     1053 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502FD0>], ['/content/celebrity-face-recognition/data/processed/cropped/Xuan Bac/Xuan Bac_17.png'])
# Images processed:     1054 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935021D0>], ['/content/celebrity-face-recognition/data/processed/cropped/Xuan Bac/Xuan Bac_18.png'])
# Images processed:     1055 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502E48>], ['/content/celebrity-face-recognition/data/processed/cropped/Xuan Bac/Xuan Bac_19.png'])
# Images processed:     1056 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502898>], ['/content/celebrity-face-recognition/data/processed/cropped/Xuan Bac/Xuan Bac_2.png'])
# Images processed:     1057 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502EF0>], ['/content/celebrity-face-recognition/data/processed/cropped/Xuan Bac/Xuan Bac_20.png'])
# Images processed:     1058 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502E10>], ['/content/celebrity-face-recognition/data/processed/cropped/Xuan Bac/Xuan Bac_21.png'])
# Images processed:     1059 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935026A0>], ['/content/celebrity-face-recognition/data/processed/cropped/Xuan Bac/Xuan Bac_22.png'])
# Images processed:     1060 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502390>], ['/content/celebrity-face-recognition/data/processed/cropped/Xuan Bac/Xuan Bac_23.png'])
# Images processed:     1061 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935022B0>], ['/content/celebrity-face-recognition/data/processed/cropped/Xuan Bac/Xuan Bac_24.png'])
# Images processed:     1062 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935021D0>], ['/content/celebrity-face-recognition/data/processed/cropped/Xuan Bac/Xuan Bac_25.png'])
# Images processed:     1063 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502898>], ['/content/celebrity-face-recognition/data/processed/cropped/Xuan Bac/Xuan Bac_26.png'])
# Images processed:     1064 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935024E0>], ['/content/celebrity-face-recognition/data/processed/cropped/Xuan Bac/Xuan Bac_27.png'])
# Images processed:     1065 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935022B0>], ['/content/celebrity-face-recognition/data/processed/cropped/Xuan Bac/Xuan Bac_28.png'])
# Images processed:     1066 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502358>], ['/content/celebrity-face-recognition/data/processed/cropped/Xuan Bac/Xuan Bac_29.png'])
# Images processed:     1067 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502550>], ['/content/celebrity-face-recognition/data/processed/cropped/Xuan Bac/Xuan Bac_3.png'])
# Images processed:     1068 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502390>], ['/content/celebrity-face-recognition/data/processed/cropped/Xuan Bac/Xuan Bac_4.png'])
# Images processed:     1069 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502E10>], ['/content/celebrity-face-recognition/data/processed/cropped/Xuan Bac/Xuan Bac_5.png'])
# Images processed:     1070 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502198>], ['/content/celebrity-face-recognition/data/processed/cropped/Xuan Bac/Xuan Bac_6.png'])
# Images processed:     1071 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502358>], ['/content/celebrity-face-recognition/data/processed/cropped/Xuan Bac/Xuan Bac_7.png'])
# Images processed:     1072 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502550>], ['/content/celebrity-face-recognition/data/processed/cropped/Xuan Bac/Xuan Bac_8.png'])
# Images processed:     1073 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935026A0>], ['/content/celebrity-face-recognition/data/processed/cropped/Xuan Bac/Xuan Bac_9.png'])
# Images processed:     1074 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502A20>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_1.png'])
# Images processed:     1075 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935023C8>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_10.png'])
# Images processed:     1076 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502A20>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_11.png'])
# Images processed:     1077 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502240>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_12.png'])
# Images processed:     1078 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502470>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_13.png'])
# Images processed:     1079 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502358>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_14.png'])
# Images processed:     1080 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935024E0>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_15.png'])
# Images processed:     1081 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502208>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_16.png'])
# Images processed:     1082 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935026A0>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_17.png'])
# Images processed:     1083 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502358>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_18.png'])
# Images processed:     1084 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502EB8>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_19.png'])
# Images processed:     1085 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502940>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_2.png'])
# Images processed:     1086 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502EB8>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_20.png'])
# Images processed:     1087 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502E48>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_21.png'])
# Images processed:     1088 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502550>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_22.png'])
# Images processed:     1089 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502EB8>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_23.png'])
# Images processed:     1090 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502908>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_24.png'])
# Images processed:     1091 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502EB8>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_25.png'])
# Images processed:     1092 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502EF0>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_26.png'])
# Images processed:     1093 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502E10>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_27.png'])
# Images processed:     1094 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502470>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_28.png'])
# Images processed:     1095 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935026A0>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_29.png'])
# Images processed:     1096 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502470>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_3.png'])
# Images processed:     1097 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502E10>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_30.PNG'])
# Images processed:     1098 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA4935023C8>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_31.png'])
# Images processed:     1099 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502550>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_32.png'])
# Images processed:     1100 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502940>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_33.png'])
# Images processed:     1101 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502550>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_34.png'])
# Images processed:     1102 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502940>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_35.png'])
# Images processed:     1103 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502208>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_36.png'])
# Images processed:     1104 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502898>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_37.png'])
# Images processed:     1105 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502208>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_4.png'])
# Images processed:     1106 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502898>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_5.png'])
# Images processed:     1107 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502940>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_6.png'])
# Images processed:     1108 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502470>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_7.png'])
# Images processed:     1109 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502668>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_8.png'])
# Images processed:     1110 of     1110([<PIL.Image.Image image mode=RGB size=160x160 at 0x7FA493502EF0>], ['/content/celebrity-face-recognition/data/processed/cropped/Đoan Van Hau/Đoan Van Hau_9.png'])

# %%
# !cp -r -f data /content/drive/My\ Drive/celebrity-face-recognition/
